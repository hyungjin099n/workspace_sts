# %%
import matplotlib.pylab as plt

#한글 폰트 설정
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
x = [1,2,3]
y = [2,4,8]

# %%
plt.plot(x, y)

# %%
plt.plot(x, y)
plt.text(2, 6, 'text')
# Out:
# Text(2, 6, 'text')

# %%
#list(enumerate(y))

plt.plot(x, y, marker='o')

for idx, txt in enumerate(y):
    #plt.text(x[idx], y[idx]+0.3, txt) #글자가 나타날 x위치, 글자가 나타날 y위치, 나타낼 글자
    plt.text(x[idx], y[idx]+0.3, txt, ha='center', color='blue') #글자가 나타날 x위치, 글자가 나타날 y위치, 나타낼 글자
