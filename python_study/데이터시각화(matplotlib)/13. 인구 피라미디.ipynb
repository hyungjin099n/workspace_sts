# %%
import matplotlib
import matplotlib.pylab as plt
import pandas as pd
import numpy as np

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.size'] = 15

# %% [markdown]
# ### 남자 데이터

# %%
df_m = pd.read_excel('2012_연령별인구현황_월간.xlsx', skiprows=3, index_col='행정기관', usecols='B, E:Y')
df_m.head(3) #3개 레코드만 조회
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       1,194,251  1,213,376  1,561,629  1,854,482  1,738,259  1,724,043
# 서울특별시      214,651    210,833    269,171    335,828    343,797    403,003
# 부산광역시       68,006     68,704     94,802    124,564    125,907    119,554
#
#             30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                 ...
# 전국       2,082,375  2,090,117  2,366,748  2,146,911  ...  1,669,110
# 서울특별시      478,692    435,832    467,119    405,386  ...    340,533
# 부산광역시      139,963    130,469    148,507    141,218  ...    140,426
#
#             60~64세   65~69세   70~74세   75~79세   80~84세  85~89세  90~94세 95~99세  \
# 행정기관
# ...

# %%
#df_m.iloc[0] #0번쨰 row 데이터 조회 
#df_m.iloc[0].str.replace(',', '').astype(int)
df_m.iloc[0] = df_m.iloc[0].str.replace(',', '').astype(int)
#df_m.iloc[0]

# %%
df_m.head(10)
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국         1194251  1213376  1561629  1854482  1738259  1724043  2082375
# 서울특별시      214,651  210,833  269,171  335,828  343,797  403,003  478,692
# 부산광역시       68,006   68,704   94,802  124,564  125,907  119,554  139,963
# 대구광역시       53,515   58,332   81,268  101,110   96,078   81,830   92,228
# 인천광역시       69,453   68,555   86,574  106,435  102,297   98,705  120,739
# 광주광역시       37,063   40,630   54,516   62,341   52,844   49,337   59,014
# 대전광역시       38,429   40,115   51,207   60,556   56,379   53,418   62,139
# 울산광역시       29,835   29,331   39,035   49,119   43,937   39,268   48,875
# 세종특별자치시      2,910    2,848    3,216    3,314    3,306    3,377    4,436
# 경기도        319,810  326,080  399,609  451,619  403,806  398,826  507,429
#
#             35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                  ...
# ...

# %% [markdown]
# ### 여자 데이터

# %%
df_w = pd.read_excel('2012_연령별인구현황_월간.xlsx', skiprows=3, index_col='행정기관', usecols='B, AB:AV')
df_w.head(3) #3개 레코드만 조회
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국       1,125,978  1,130,011  1,428,985  1,649,136  1,557,402  1,617,233
# 서울특별시      203,170    198,656    248,498    303,755    338,145    411,706
# 부산광역시       64,361     63,949     85,014    106,745    110,771    112,815
#
#           30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1  \
# 행정기관                                                 ...
# 전국       1,995,998  2,017,083  2,275,185  2,050,878  ...  1,677,975
# 서울특별시      470,794    424,818    460,579    406,140  ...    367,754
# 부산광역시      134,020    126,374    149,532    146,064  ...    147,373
#
#           60~64세.1   65~69세.1 70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1  \
# 행정기관
# ...

# %%
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns = df_m.columns #컬럼명 통일

# %%
df_w.iloc[0] = df_w.iloc[0].str.replace(',', '').astype(int)
df_w.head(5)
# Out:
#             0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국       1125978  1130011  1428985  1649136  1557402  1617233  1995998
# 서울특별시    203,170  198,656  248,498  303,755  338,145  411,706  470,794
# 부산광역시     64,361   63,949   85,014  106,745  110,771  112,815  134,020
# 대구광역시     49,929   53,128   71,445   85,389   75,924   73,643   93,166
# 인천광역시     65,716   64,567   80,098   96,544   94,783   93,609  114,680
#
#           35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                ...
# 전국       2017083  2275185  2050878  ...  1677975  1233917  1006707   988465
# 서울특별시    424,818  460,579  406,140  ...  367,754  266,017  209,740  171,117
# 부산광역시    126,374  149,532  146,064  ...  147,373  109,632   81,113   72,837
# 대구광역시     98,450  118,037  110,350  ...   87,182   65,898   48,626   47,197
# 인천광역시    114,619  131,914  124,146  ...   87,952   57,875   46,702   42,825
#
# ...

# %% [markdown]
# ### 데이터 시각화

# %%
plt.figure(figsize=(10, 7))
plt.barh(df_m.columns, -df_m.iloc[0] // 1000) #단위 : 천 명
plt.barh(df_w.columns, df_w.iloc[0] // 1000)
plt.title('2011년 대한민국 인구 피라미드')
# Out:
# Text(0.5, 1.0, '2011년 대한민국 인구 피라미드')
