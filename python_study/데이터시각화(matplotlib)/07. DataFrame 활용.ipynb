# %%
import matplotlib
import matplotlib.pylab as plt
import pandas as pd

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False
#matplotlib.rcParams['font.size'] = 15

# %%
df = pd.read_excel('../데이터분석(Pandas)/student.xlsx')
df
#df.columns
# Out:
# Index(['학번', '이름', '학급', '국어점수', '영어점수', '평균', '취미'], dtype='object')

# %%
plt.plot(df['학번'], df['국어점수'])

# %%
plt.plot(df['학번'], df['국어점수'])
plt.plot(df['학번'], df['영어점수'])

# %%
plt.plot(df['학번'], df['국어점수'])
plt.plot(df['학번'], df['영어점수'])
#plt.grid()
#plt.grid(axis='x')
plt.grid(axis='y', color='purple', alpha=0.3, ls='--', lw=2)
